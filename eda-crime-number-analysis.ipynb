# %% [markdown]
# <a href="https://www.kaggle.com/code/yutodennou/eda-crime-number-analysis?scriptVersionId=153518450" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 🎉Purpose

# %% [markdown]
# To visualize how crime numbers go like increasing/decreasing by year.

# %% [markdown]
# # 🗃️Import Libs

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/crime-numbers-in-japan-by-2016/crime_numbers_in_japan.csv

# %%
import plotly.graph_objects as go
import plotly.io as pio

# %% [markdown]
# # 📏Preprocessing

# %%
df = pd.read_csv(f'../input/crime-numbers-in-japan-by-2016/{filename}')
df.head(20)
# Out:
#     year  crime code          crime category  \
# 0   2016         100  total number of crimes
# 1   2016         110               felonious
# 2   2016         120               felonious
# 3   2016         130               felonious
# 4   2016         140               felonious
# 5   2016         150               felonious
# 6   2016         160                 violent
# 7   2016         170                 violent
# 8   2016         180                 violent
# 9   2016         190                 violent
# 10  2016         200                 violent
# 11  2016         210                 violent
# 12  2016         220                 violent
# 13  2016         230                 larceny
# 14  2016         240                 larceny
# 15  2016         250                 larceny
# 16  2016         260                 larceny
# 17  2016         270            intellectual
# 18  2016         280            intellectual
# 19  2016         290            intellectual
#
# ...

# %%
[print(i) for i in df['crime category'].unique()]
# Out:
# total number of crimes
# felonious
# violent
# larceny
# intellectual
# moral
# other crimes
# [None, None, None, None, None, None, None]

# %% [markdown]
# # 📈Visualize

# %% [markdown]
# ## 1. Number of Cases

# %%
tmp = df[df['crime category']=='total number of crimes']
tmp.head(15)
# Out:
#      year  crime code          crime category crime name detailed crime name  \
# 0    2016         100  total number of crimes        NaN                 NaN
# 42   2015         100  total number of crimes        NaN                 NaN
# 84   2014         100  total number of crimes        NaN                 NaN
# 126  2013         100  total number of crimes        NaN                 NaN
# 168  2012         100  total number of crimes        NaN                 NaN
# 210  2011         100  total number of crimes        NaN                 NaN
# 252  2010         100  total number of crimes        NaN                 NaN
# 294  2009         100  total number of crimes        NaN                 NaN
# 336  2008         100  total number of crimes        NaN                 NaN
# 378  2007         100  total number of crimes        NaN                 NaN
# 420  2006         100  total number of crimes        NaN                 NaN
#
# ...

# %%
x = tmp['year']
s1 = 'reported cases'
y1 = tmp[s1]
s2 = 'cleared cases'
y2 = tmp[s2]
plot = [
    go.Bar(
        x=x, y=y1, name=s1,
        marker_color='rgb(55, 83, 109)'
    ),
    go.Bar(
        x=x, y=y2, name=s2,
        marker_color='rgb(26, 118, 255)'
    )
]

layout = go.Layout(
    title='Amount of Cases in Japan',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='Cases',
        tick0=100000,
        dtick=100000,
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=1.0, y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    bargap=0.15,
    bargroupgap=0.1
)

fig = go.Figure(data=plot, layout=layout)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# ## 2. Cases by Crime Category

# %%
tmp = df[df['crime category']!='total number of crimes']
tmp.head(15)
# Out:
#     year  crime code crime category                                crime name  \
# 1   2016         110      felonious                                       NaN
# 2   2016         120      felonious                                  homicide
# 3   2016         130      felonious                                  robbery
# 4   2016         140      felonious                                     arson
# 5   2016         150      felonious                                      rape
# 6   2016         160        violent                                       NaN
# 7   2016         170        violent  unlawful assembly with dangerous weapons
# 8   2016         180        violent                                  violence
# 9   2016         190        violent                             bodily injury
# 10  2016         200        violent                             bodily injury
# 11  2016         210        violent                              intimidation
# ...

# %% [markdown]
# ### 2-1. Sum of Cases by Each Crime Category

# %%
y1_data = []
y2_data = []
for c_c in tmp['crime category'].unique():
    tmp2 = tmp[tmp['crime category']==c_c]
    y1_data.append(tmp2['reported cases'].sum())
    y2_data.append(tmp2['cleared cases'].sum())

# %%
x = tmp['crime category'].unique()
s1 = 'reported cases'
s2 = 'cleared cases'
plot = [
    go.Bar(
        x=x, y=y1_data, name=s1,
        marker_color='rgb(55, 83, 109)'
    ),
    go.Bar(
        x=x, y=y2_data, name=s2,
        marker_color='rgb(26, 118, 255)'
    )
]

layout = go.Layout(
    title='Sum of Cases for 10 Years from 2006 to 2016',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='Cases',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=1.0, y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    bargap=0.15,
    bargroupgap=0.1
)

fig = go.Figure(data=plot, layout=layout)
fig.show()
# Out:
# <div>                            <div id="209f572d-8ad8-4eeb-ba84-a436ef21e182" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("209f572d-8ad8-4eeb-ba84-a436ef21e182")) {                    Plotly.newPlot(                        "209f572d-8ad8-4eeb-ba84-a436ef21e182",                        [{"marker":{"color":"rgb(55, 83, 109)"},"name":"reported cases","x":["felonious","violent","larceny","intellectual","moral","other crimes"],"y":[163822.0,1469094.0,25004992.0,1232120.0,355479.0,5141731.0],"type":"bar"},{"marker":{"color":"rgb(26, 118, 255)"},"name":"cleared cases","x":["felonious","violent","larceny","intellectual","moral","other crimes"],"y":[122974.0,1063384.0,6797328.0,652165.0,215132.0,1659077.0],"type":"bar"}],                        {"bargap
# ...

# %% [markdown]
# ### 2-2. Each Crime Category with Error Bars

# %%
y1_mean = []
y1_std = []
y2_mean = []
y2_std = []
for c_c in tmp['crime category'].unique():
    tmp2 = tmp[tmp['crime category']==c_c]
    y1_mean.append(tmp2['reported cases'].mean())
    y1_std.append(tmp2['reported cases'].std())
    y2_mean.append(tmp2['cleared cases'].mean())
    y2_std.append(tmp2['cleared cases'].std())

# %%
fig = go.Figure()
x = tmp['crime category'].unique()
s1 = 'reported cases'
s2 = 'cleared cases'
plot = [
    go.Bar(
        x=x, y=y1_mean, name=s1,
        marker_color='rgb(55, 83, 109)',
        error_y=dict(type='data', array=y1_std)
    ),
    go.Bar(
        x=x, y=y2_mean, name=s2,
        marker_color='rgb(26, 118, 255)',
        error_y=dict(type='data', array=y2_std)
    )
]
layout = go.Layout(
    title='Average Cases for 10 Years from 2006 to 2016',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='Average Cases',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=1.0, y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    bargap=0.15,
    bargroupgap=0.1
)
fig = go.Figure(data=plot, layout=layout)
fig.show()
# Out:
# <div>                            <div id="341c7071-f707-41e8-8a86-971594da4e56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("341c7071-f707-41e8-8a86-971594da4e56")) {                    Plotly.newPlot(                        "341c7071-f707-41e8-8a86-971594da4e56",                        [{"error_y":{"array":[2576.76585759135,23165.622142641438,400684.4397982476,19813.406786398813,4425.221384787105,86416.27582358697],"type":"data"},"marker":{"color":"rgb(55, 83, 109)"},"name":"reported cases","x":["felonious","violent","larceny","intellectual","moral","other crimes"],"y":[2978.581818181818,19079.14285714286,568295.2727272727,9701.732283464567,6463.254545454545,58428.76136363636],"type":"bar"},{"error_y":{"array":[1824.9932589700697,16783.155128633
# ...

# %% [markdown]
# ### 2-3. Cases Plot by Years

# %%
years = tmp['year'].unique()
y1 = {}
y2 = {}
for year in years:
    y1_data = []
    y2_data = []
    for c_c in tmp['crime category'].unique():
        tmp2 = tmp[(tmp['crime category']==c_c)|(tmp['year']==year)|(tmp['crime name'].isnull())]
        y1_data.append(tmp2['reported cases'].sum())
        y2_data.append(tmp2['cleared cases'].sum())
    y1[year] = y1_data
    y2[year] = y2_data

# %%
for year in years:
    x = tmp['crime category'].unique()
    s1 = 'reported cases'
    s2 = 'cleared cases'
    plot = [
        go.Bar(
            x=x, y=y1[year], name=s1,
            marker_color='rgb(55, 83, 109)'
        ),
        go.Bar(
            x=x, y=y2[year], name=s2,
            marker_color='rgb(26, 118, 255)'
        )
    ]

    layout = go.Layout(
        title=f'Cases in {year}',
        xaxis_tickfont_size=14,
        yaxis=dict(
            title='Cases',
            titlefont_size=16,
            tickfont_size=14,
        ),
        legend=dict(
            x=1.0, y=1.0,
            bgcolor='rgba(255, 255, 255, 0)',
            bordercolor='rgba(255, 255, 255, 0)'
        ),
        bargap=0.15,
        bargroupgap=0.1
    )

    fig = go.Figure(data=plot, layout=layout)
    fig.show()
# Out:
# <div>                            <div id="99499694-545b-429f-bce8-8671418206a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99499694-545b-429f-bce8-8671418206a1")) {                    Plotly.newPlot(                        "99499694-545b-429f-bce8-8671418206a1",                        [{"marker":{"color":"rgb(55, 83, 109)"},"name":"reported cases","x":["felonious","violent","larceny","intellectual","moral","other crimes"],"y":[17710914.0,18307175.0,29413481.0,18226171.0,17847027.0,20033135.0],"type":"bar"},{"marker":{"color":"rgb(26, 118, 255)"},"name":"cleared cases","x":["felonious","violent","larceny","intellectual","moral","other crimes"],"y":[5620102.0,6045399.0,8753068.0,5882568.0,5688681.0,6335492.0],"type":"bar"}],                      
# ...
