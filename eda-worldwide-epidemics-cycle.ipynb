# %% [markdown]
# <a href="https://www.kaggle.com/code/yutodennou/eda-worldwide-epidemics-cycle?scriptVersionId=148884099" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 🗃️Import Libs

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# # 🗂️Import Data

# %%
df = pd.read_csv("/kaggle/input/list-of-epidemics-and-pandemics-in-world-history/Chronological Table of Epidemic and Pandemic Events in human History.csv")
df.head()
# Out:
#    Unnamed: 0                      Event                          Date  \
# 0           0  1350 BC plague of Megiddo                       1350 BC
# 1           1           Plague of Athens                    430–426 BC
# 2           2            412 BC epidemic                        412 BC
# 3           3            Antonine Plague  165–180 (possibly up to 190)
# 4           4             Jian'an Plague                           217
#
#                                    Location  \
# 0                   Megiddo, land of Canaan
# 1            Greece, Libya, Egypt, Ethiopia
# 2  Greece (Northern Greece, Roman Republic)
# 3                              Roman Empire
# 4                               Han Dynasty
#
#                                              Disease Death toll (estimate)  \
# 0  Amarna letters EA 244, Biridiya, mayor of Megi...               Unknown
# 1  Unknown, possibly typhus, typhoid fever or vir...        75,000–100,000
# 2                        Unknown, possibly influenza               Unknown
# 3                         Unknown, possibly smallpox          5–10 million
# 4  Unknown, possibly typhoid fever or viral hemor...               Unknown
#
#                Ref.
# 0              [26]
# 1  [27][28][29][30]
# 2              [31]
# 3          [32][33]
# 4          [34][35]

# %% [markdown]
# # 🔍EDA

# %% [markdown]
# ## 📏Preprocessing

# %% [markdown]
# ### Date

# %%
df.Date.unique()
# Out:
# array(['1350 BC', '430–426 BC', '412 BC', '165–180 (possibly up to 190)',
#        '217', '249–262', '541–549', '590', '627–628', '638–639',
#        '664–689', '698–701', '735–737', '746–747', '1346–1353',
#        '1485–1551', '1489', '1510', '1519–1520', '1545–1548', '1557–1559',
#        '1561–1562', '1563–1564', '1576–1580', '1582–1583', '1592–1596',
#        '1592–1593', '1596–1602', '1600–1650', '1603', '1616–1620',
#        '1629–1631', '1632–1635', '1633–1634', '1634–1640', '1636–1637',
#        '1633–1644', '1647–1652', '1648', '1656–1658', '1663–1664',
#        '1665–1666', '1668', '1675–1676', '1676–1685', '1677–1678', '1679',
#        '1681', '1687', '1693', '1699', '1702', '1702–1703', '1707–1709',
#        '1710–1712', '1713–1715', '1720–1722', '1721–1722', '1730',
#        '1732–1733', '1733', '1735–1741', '1738', '1738–1739', '1741',
#        '1743', '1759', '1760', '1762', '1763', '1770–1772', '1772',
#        '1772–1773', '1775–1776', '1775–1782', '1778', '1788', '1789–1790',
#        '1793', '1800–1803', '1801', '1802–1803', '1812', '1812–1819',
#        '1813–1814', '1813', '1817–1819', '1817–1824', '1820', '1821',
#        '1826–1837', '1828–1829', '1829', '1829–1833', '1829–1835',
#        '1834–1836', '1837–1838', '1841', '1847–1848', '1847', '1848–1849',
#        '1853', '1846–1860', '1854', '1855', '1855–1960', '1855–1857',
#        '1857', '1857–1859', '1862–1863', '1861–1865', '1863–1875', '1867',
#        '1871', '1870–1875', '1875', '1875–1876', '1876', '1878',
#        '1881–1896', '1885', '1889–1890', '1894–1929', '1896–1905',
#        '1896–1906', '1899', '1899–1923', '1900–1904', '1900', '1900–1920',
#        '1901–2009', '1903', '1906–1936', '1910–1911', '1915–1926', '1916',
#        '1918–1920', '1918–1922', '1924', '1924–1925', '1927', '1929–1930',
#        '1937', '1940', '1942–1944', '1946', '1947', '1948–1952',
#        '1957–1958', '1960–1962', '1961–1975', '1968–1970', '1971', '1972',
#        '1972–1973', '1973', '1974', '1977–1979', '1979', '1981–present',
#        '1984', '1986', '1987', '1988', '1991', '1991–1993', '1994',
#        '1996–2001', '1996', '1998–1999', '1998–2000', '2000', '2001',
#        '2002–2004', '2003–2019', '2004', '2004–2005', '2005', '2006',
#        '2006–2007', '2007', '2007–2018', '2008', '2008–2017', '2008–2009',
#        '2009', '2009–2010', '2010–2019', '2010–2014', '2011', '2012',
#        '2012–2021', '2013', '2013–2014', '2013–2016', '2013–2015',
#        '2013–2019', '2014–2017', '2014–2015', '2015', '2015–2016', '2016',
#        '2016–2022', '2017', '2018', '2018–2020', '2018–2019', '2019–2020',
#        '2019', '2019–2021', '2019–present', '2020', '2021-2022',
#        '2021–2022', '2022–present', '2022–2023'], dtype=object)

# %%
df['Date'] = df['Date'].replace('2021-2022', '2021–2022')

# %%
def get_start_date(date):
    if 'BC' in date:
        _date = date.split(' BC')[0]
        if '–' in _date:
            _date = int(_date.split('–')[0])*(-1)
        else:
            _date = int(_date)*(-1)
    elif ('BC' not in date) and ('–' in date):
        _date = int(date.split('–')[0])
    else:
        _date = int(date)
    return _date

# %%
def get_end_date(date):
    if 'BC' in date:
        _date = date.split(' BC')[0]
        if '–' in _date:
            _date = int(_date.split('–')[1][0:3])*(-1)
        else:
            _date = int(_date[0:3])*(-1)
    elif ('BC' not in date) & ('–' in date):
        _date = date.split('–')[1]
        if _date=='present':
            _date = 2023
        else:
            _date = int(_date[0:4])
    else:
        _date = int(date)
    return _date

# %%
df['start_date'] = df['Date'].apply(get_start_date)
df['end_date'] = df['Date'].apply(get_end_date)

# %% [markdown]
# ### Location

# %%
countries_series = map(lambda s: s.split(', '), df.Location.unique())
countries = set([x for y in countries_series for x in y])
countries
# Out:
# {'Africa',
#  'Americas',
#  'Amsterdam',
#  'Angola',
#  'Angola and Democratic Republic of the Congo',
#  'Argentina',
#  'Asia',
#  'Asia-Pacific',
#  'Augsburg',
#  'Australia',
#  'Austria',
#  'Balkans',
#  'Bangladesh',
#  'Barcelona',
#  'Bilad al-Sham',
#  'Bolivia',
#  'Bombay',
#  'Boston',
#  'Brazil',
#  'Britain (England) and later continental Europe',
#  'British Isles',
#  'British North America',
#  'Buenos Aires',
#  'Byzantine Empire',
#  'Cambodia',
#  'Canada',
#  'Canada and United States',
#  'Cartagena',
#  'Central America',
#  'Ceylon',
#  'Chad',
#  'Charleston',
#  'Charleston and Philadelphia',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo Basin',
#  'Copenhagen',
#  'Croydon',
#  'Cuba',
#  'Czech Kingdom',
#  'Cádiz',
#  'Darfur',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo and Uganda',
#  'Denmark',
#  'Dominican Republic',
#  'East Africa',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'England',
#  'Ethiopia',
#  'Eurasia and North Africa',
#  'Europe',
#  'Europe and West Asia',
#  'Fiji',
#  'Flint',
#  'France',
#  'Fremantle',
#  'Georgia',
#  'Germany',
#  'Great Plains',
#  'Greece',
#  'Greece (Northern Greece',
#  'Guatemala',
#  'Haiti',
#  'Han Dynasty',
#  'Havana',
#  'Hawaiian Kingdom',
#  'Hong Kong',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Italy',
#  'Ituri Province',
#  'Japan',
#  'Kuala Koh',
#  'Latin America',
#  'Liberia',
#  'Libya',
#  'Lisbon',
#  'Lithuania',
#  'London',
#  'London and Westminster',
#  'Los Angeles',
#  'Luanda',
#  'Madagascar',
#  'Malaysia',
#  'Mali',
#  'Malta',
#  'Massachusetts Bay Colony',
#  'Megiddo',
#  'Mesopotamia',
#  'Messina',
#  'Mexico',
#  'Michigan',
#  'Middle East',
#  'Minnesota',
#  'Mississippi Valley',
#  'Montevideo',
#  'Montreal',
#  'Native populations in what is now the Pacific Northwest of the United States',
#  'Netherlands',
#  'New England',
#  'New France',
#  'New Orleans',
#  'New South Wales',
#  'New York City',
#  'New Zealand',
#  'Nigeria',
#  'Norfolk and Portsmouth',
#  'North Africa',
#  'North America',
#  'Oju',
#  'Ottoman Empire',
#  'Pacific Northwest',
#  'Pakistan',
#  'Papua New Guinea',
#  'Persia',
#  'Peru',
#  'Peshawar',
#  'Philadelphia',
#  'Philippines',
#  'Porto',
#  'Portugal',
#  'Prague',
#  'Province of Carolina',
#  'Province of New Jersey',
#  'Province of New York',
#  'Pueblo Indians in northern New Spain (what is now the Southwestern United States)',
#  'Puerto Rico',
#  'Queensland',
#  'Roman Empire',
#  'Roman Republic)',
#  'Romania',
#  'Rome',
#  'Russia',
#  'Saint-Domingue',
#  'Samoa',
#  'San Francisco',
#  'Savannah',
#  'Seneca nation',
#  'Shanghai',
#  'Sicily',
#  'Sierra Leone',
#  'Singapore',
#  'South Africa',
#  'South America',
#  'Southeast Asia and Egypt',
#  'Southern New England',
#  'Southern United States (especially Louisiana and Florida)',
#  'Southern United States (especially New Orleans)',
#  'Spain',
#  'Sri Lanka',
#  'Staphorst',
#  'Sudan',
#  'Sweden',
#  'Sydney',
#  'Syria',
#  'Tenerife',
#  'Thirteen Colonies',
#  'Thirteen Colonies and New France',
#  'Uganda',
#  'United Kingdom',
#  'United States',
#  'United States and Canada',
#  'Uruguay',
#  'Victoria',
#  'Vienna',
#  'Vietnam',
#  'West Africa',
#  'West Asia',
#  'Western Australia',
#  'Western Sahara',
#  'Worldwide',
#  'Wyandot people',
#  'Yemen',
#  'Yugoslavia',
#  'Zimbabwe',
#  'and Americas',
#  'especially the Wampanoag people',
#  'land of Canaan',
#  'present-day Pittsburgh area',
#  'primarily concentrated in Guinea'}

# %% [markdown]
# ### Extract dataframe of Worldwide Diseases

# %%
df_world = df[df['Location'].str.contains('Worldwide')]
df_world
# Out:
#      Unnamed: 0                                              Event  \
# 101         101                       1847–1848 influenza epidemic
# 104         104                             Third cholera pandemic
# 109         109                              Third plague pandemic
# 127         127                                 1889–1890 pandemic
# 140         140              1915 encephalitis lethargica pandemic
# 142         142            1918 influenza pandemic ('Spanish flu')
# 147         147                     1929–1930 psittacosis pandemic
# 155         155         1957–1958 influenza pandemic ('Asian flu')
# 157         157                           Seventh cholera pandemic
# 158         158                                      Hong Kong flu
# 164         164                                   1977 Russian flu
# 166         166                                  HIV/AIDS pandemic
# 181         181                            2002–2004 SARS outbreak
# 212         212                            2009 swine flu pandemic
# 213         213                            2009 swine flu pandemic
# 219         219  2012 Middle East respiratory syndrome coronavi...
# 222         222               Western African Ebola virus epidemic
# 229         229                        2015–16 Zika virus epidemic
# 245         245                                  COVID-19 pandemic
# 250         250       2022 hepatitis of unknown origin in children
# 251         251                       2022–2023 monkeypox outbreak
#
#              Date                                           Location  \
# 101     1847–1848                                          Worldwide
# 104     1846–1860                                          Worldwide
# 109     1855–1960                                          Worldwide
# 127     1889–1890                                          Worldwide
# 140     1915–1926                                          Worldwide
# 142     1918–1920                                          Worldwide
# 147     1929–1930                                          Worldwide
# 155     1957–1958                                          Worldwide
# 157     1961–1975                                          Worldwide
# 158     1968–1970                                          Worldwide
# 164     1977–1979                                          Worldwide
# 166  1981–present                                          Worldwide
# 181     2002–2004                                          Worldwide
# 212     2009–2010                                          Worldwide
# 213     2009–2010                                          Worldwide
# 219     2012–2021                                          Worldwide
# 222     2013–2016  Worldwide, primarily concentrated in Guinea, L...
# 229     2015–2016                                          Worldwide
# 245  2019–present                                          Worldwide
# 250     2021–2022                                          Worldwide
# 251  2022–present                                          Worldwide
#
#                                                Disease  \
# 101                                          Influenza
# 104                                            Cholera
# 109                                     Bubonic plague
# 127  Influenza or Human coronavirus OC43 / HCoV-OC4...
# 140                            Encephalitis lethargica
# 142          Influenza A virus subtype H1N1 H1N1 virus
# 147                                        Psittacosis
# 155                     Influenza A virus subtype H2N2
# 157                            Cholera (El Tor strain)
# 158          Influenza A virus subtype H3N2 H3N2 virus
# 164                     Influenza A virus subtype H1N1
# 166              HIV/AIDS Human immunodeficiency virus
# 181           Severe acute respiratory syndrome / SARS
# 212                     Influenza A virus subtype H1N1
# 213                     Influenza A virus subtype H1N1
# 219        Middle East respiratory syndrome / MERS-CoV
# 222                           Ebola Ebola virus virion
# 229                                         Zika virus
# 245  Coronavirus disease 2019 / COVID-19 SARS-CoV-2...
# 250  Hepatitis by Adenovirus variant AF41 (Unconfir...
# 251                                    Monkeypox virus
#
#                                  Death toll (estimate)                  Ref.  \
# 101                                            Unknown                 [143]
# 104                                         1 million+                 [145]
# 109                    12–15 million (India and China)            [150][151]
# 127                                          1 million                 [169]
# 140                                             500000       [182][183][184]
# 142                                     17–100 million       [186][187][188]
# 147                                               100+                 [193]
# 155                                        1–4 million       [186][199][200]
# 157                            36,000[citation needed]                 [202]
# 158                                        1–4 million       [186][199][200]
# 164                                             700000            [208][209]
# 166                             42 million (as of 2023                 [211]
# 181                                                774                 [230]
# 212  Lab confirmed deaths: 18,449 (reported to the ...                 [260]
# 213  Estimated death toll: 284,000 (possible range ...                 [261]
# 219                              941 (as of 8 May 2021            [269][270]
# 222                                            11,323+       [272][273][274]
# 229                                                 53                 [283]
# 245                   7–29.3 million (as of April 2023  [301][302][303][304]
# 250                                                 18       [309][310][311]
# 251                                                280  [312][313][314][315]
#
#      start_date  end_date
# 101        1847      1848
# 104        1846      1860
# 109        1855      1960
# 127        1889      1890
# 140        1915      1926
# 142        1918      1920
# 147        1929      1930
# 155        1957      1958
# 157        1961      1975
# 158        1968      1970
# 164        1977      1979
# 166        1981      2023
# 181        2002      2004
# 212        2009      2010
# 213        2009      2010
# 219        2012      2021
# 222        2013      2016
# 229        2015      2016
# 245        2019      2023
# 250        2021      2022
# 251        2022      2023

# %% [markdown]
# ## 📈Visualize

# %% [markdown]
# ### Histogram of the Epidemic Cycle

# %%
fig = px.histogram(df_world, x="start_date", 
                   nbins=100, 
                   hover_name="Event", 
                   hover_data=["Date","Disease"], 
                   labels={"start_date": "year"},
                   title="When Epidemics Happened")
fig.update_layout(xaxis={'dtick':5})
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="f237232f-7d6a-494a-b6bb-7be6d9e70f80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f237232f-7d6a-494a-b6bb-7be6d9e70f80")) {                    Plotly.newPlot(                        "f237232f-7d6a-494a-b6bb-7be6d9e70f80",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":100,"offsetgroup":"","orientation":"v","showlegend":false,"x":[1847,1846,1855,1889,1915,1918,1929,1957,1961,1968,1977,1981,2002,2009,2009,2012,2013,2015,2019,2021,2022],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"s ...

# %%
cycle = abs(df_world.start_date.diff())
print(cycle.describe())
fig = px.histogram(cycle, 
                   nbins=30, 
                   labels={"value": "Year Cycle of Epidemics"},
                   title="Histogram of the Epidemic Cycle")
fig.show()
# Out:
# count    20.000000
# mean      8.850000
# std      10.126957
# min       0.000000
# 25%       2.000000
# 50%       4.000000
# 75%       9.500000
# max      34.000000
# Name: start_date, dtype: float64
# <div>                            <div id="c116369b-2441-43a8-9c5f-7e1822102a9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c116369b-2441-43a8-9c5f-7e1822102a9c")) {                    Plotly.newPlot(                        "c116369b-2441-43a8-9c5f-7e1822102a9c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=start_date<br>Year Cycle of Epidemics=%{x}<br>count=%{y}<extra></extra>","legendgroup":"start_date","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"start_date","nbinsx":30,"offsetgroup":"start_date","orientation":"v","showlegend":true,"x":[null,1.0,9.0,34.0,26.0,3.0,11.0,28.0,4.0,7.0,9.0,4.0,21.0,7.0,0.0,3.0,1.0,2.0,4.0,2.0,1.0],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo"," ...

# %% [markdown]
# ### How Long the Worldwide Epidemics Continued

# %%
continuity = abs(df_world.end_date - df_world.start_date)
print(continuity.describe())
fig = px.histogram(continuity, 
                   nbins=100 , 
                   labels={"value": "How Long Epidemic Continued"},
                   title="Histogram of Epidemics Continuity"
                  )
fig.show()
# Out:
# count     21.000000
# mean      10.428571
# std       23.610530
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        9.000000
# max      105.000000
# dtype: float64
# <div>                            <div id="556ae055-d50c-4529-847a-49b256a7ed1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("556ae055-d50c-4529-847a-49b256a7ed1f")) {                    Plotly.newPlot(                        "556ae055-d50c-4529-847a-49b256a7ed1f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0<br>How Long Epidemic Continued=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","nbinsx":100,"offsetgroup":"0","orientation":"v","showlegend":true,"x":[1,14,105,1,11,2,1,1,14,2,2,42,2,1,1,9,3,1,4,1,1],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"ty ...

# %% [markdown]
# # 🌞Summary

# %% [markdown]
# * An Average of epidemic cycle is about 8 years.
# * Almost of all epidemics continued for less 1 year.
