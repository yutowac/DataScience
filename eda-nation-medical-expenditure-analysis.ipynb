# %% [markdown]
# <a href="https://www.kaggle.com/code/yutodennou/eda-nation-medical-expenditure-analysis?scriptVersionId=152142761" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 🎉Purpose¶
# To visualize how nation medical expenditure goes like increasing/decreasing by year.

# %% [markdown]
# # 🗃️Import Libs

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nation-medical-expenditure-in-japan/National_Medical_Expenditure.csv

# %%
import plotly.graph_objects as go
import plotly.io as pio

# %% [markdown]
# # 📏Preprocessing

# %%
df = pd.read_csv(f'../input/nation-medical-expenditure-in-japan/{filename}')
df.head(20)
# Out:
#     Year  NationalMedicalExpenditure  NationalMedicalExpenditure_GrowthRate  \
# 0   2020                      429665                                   -3.2
# 1   2019                      443895                                    2.3
# 2   2018                      433949                                    0.8
# 3   2017                      430710                                    2.2
# 4   2016                      421381                                   -0.5
# 5   2015                      423644                                    3.8
# 6   2014                      408071                                    1.9
# 7   2013                      400610                                    2.2
# 8   2012                      392117                                    1.6
# 9   2011                      385850                                    3.1
# 10  2010                      374202                                    3.9
# ...

# %% [markdown]
# # 📈Visualize

# %%
x = df['Year']
s1 = 'NationalMedicalExpenditure'
y1 = df[s1]
s2 = 'GrossDomesticProduct'
y2 = df[s2]
plot = [
    go.Bar(
        x=x, y=y1, name=s1,
        marker_color='rgb(55, 83, 109)'
    ),
    go.Bar(
        x=x, y=y2, name=s2,
        marker_color='rgb(26, 118, 255)'
    )
]

layout = go.Layout(
    title='Relation of National medical expenditure and Gross domestic products',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='100 million yen',
#         tick0=100000,
#         dtick=100000,
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=1.0, y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    bargap=0.15,
    bargroupgap=0.1
)

fig = go.Figure(data=plot, layout=layout)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
plot = go.Scatter(x=df[s1], y=df[s2],mode='markers')
layout = go.Layout(
    title='Relation of National medical expenditure and Gross domestic products',
    xaxis=dict(
        title=s1,
        titlefont_size=16,
        tickfont_size=14,
    ),
    yaxis=dict(
        title=s2,
        titlefont_size=16,
        tickfont_size=14,
    )
)
fig = go.Figure(data=plot, layout=layout)
fig.show()
# Out:
# <div>                            <div id="5e11ec06-871e-4683-9a91-6253640b6ec3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e11ec06-871e-4683-9a91-6253640b6ec3")) {                    Plotly.newPlot(                        "5e11ec06-871e-4683-9a91-6253640b6ec3",                        [{"mode":"markers","x":[429665,443895,433949,430710,421381,423644,408071,400610,392117,385850,374202,360067,348084,341360,331276,331289,321111,315375,309507,310998,301418,307019,295823,289149,284542,269577,257908,243631,234784,218260,206074,197290,187554,180759,170690,160159,150932,145438,138659,128709,119805,109510,100042,85686,76684,64779,53786,39496,33994,27250,24962,20780,18016,15116,13002,11224,9389,7541,6132,5130,4095,3625,3230,2897,2583,2388,2152],"y":[5355
# ...

# %% [markdown]
# # 💡Conclusion

# %% [markdown]
# - Growth of medical expenditure stopped in 1994.
# - Correlation between medical expenditure and gross domestic products is low.
