# %% [markdown]
# <a href="https://www.kaggle.com/code/yutodennou/competition-simple-xgboost-with-gridsearchcv?scriptVersionId=148087611" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 🎉Purpose

# %% [markdown]
# Making **xgboost** model for student performance with **grid search**.
#
# Grid search is useful for triyng many patterns of hyperparameter.

# %% [markdown]
# I also explain about Gridsearch in detail [here](https://www.kaggle.com/code/yutodennou/make-gridsearchcv-faster)

# %% [markdown]
# # 🗃️Import Library

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/predict-student-performance-from-game-play/sample_submission.csv
# /kaggle/input/predict-student-performance-from-game-play/train_labels.csv
# /kaggle/input/predict-student-performance-from-game-play/train.csv
# /kaggle/input/predict-student-performance-from-game-play/test.csv
# /kaggle/input/predict-student-performance-from-game-play/jo_wilder_310/competition.cpython-310-x86_64-linux-gnu.so
# /kaggle/input/predict-student-performance-from-game-play/jo_wilder_310/__init__.py
# /kaggle/input/predict-student-performance-from-game-play/jo_wilder/competition.cpython-37m-x86_64-linux-gnu.so
# /kaggle/input/predict-student-performance-from-game-play/jo_wilder/__init__.py

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import cross_val_score, train_test_split, KFold, GroupKFold, StratifiedKFold, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import f1_score

# %% [markdown]
# # 🔍Import data

# %%
COLS = ['session_id', 'index', 'elapsed_time', 'event_name', 'name', 'level',
       'page', 'room_coor_x', 'room_coor_y', 'screen_coor_x', 'screen_coor_y',
       'hover_duration', 'text', 'fqid', 'room_fqid', 'text_fqid',
       'level_group']

# %%
train = pd.read_csv("/kaggle/input/predict-student-performance-from-game-play/train.csv", usecols=COLS, 
                dtype = {'index':np.int16, 'level':np.int8, 'page':np.float32, 'room_coor_x':np.float32, 
                        'room_coor_y':np.float32, 'screen_coor_x':np.float16, 'screen_coor_y':np.float16, 
                        'hover_duration':np.float32, 'event_name':'category', 'name':'category', 
                        'text':'category', 'fqid':'category', 'room_fqid':'category', 
                        'level_group':'category'})

# %%
train_label = pd.read_csv("/kaggle/input/predict-student-performance-from-game-play/train_labels.csv")
train_label['session'] = train_label.session_id.apply(lambda x: int(x.split('_')[0]))
train_label['q'] = train_label.session_id.apply(lambda x: int(x.split('_')[-1][1:]))

# %%
categorical_features = train.select_dtypes(include = ["category","object","bool"]).columns
categorical_features = categorical_features.drop("level_group")
numerical_features = train.select_dtypes(include = ["int8","int16","int64","float16","float32","float64"]).columns

# %% [markdown]
# # 📏Preprocessing

# %%
def processing_na(train):
    print("Na of numerical features: " + str(train[numerical_features].isnull().values.sum()))
    train[numerical_features] = train[numerical_features].fillna(train[numerical_features].median())
    print("-> " + str(train[numerical_features].isnull().values.sum()))
    encoder = OrdinalEncoder()
    train[categorical_features] = encoder.fit_transform(train[categorical_features])
    print("Na of categorical features: " + str(train[categorical_features].isnull().values.sum()))
    train[categorical_features] = train[categorical_features].fillna(method="ffill")
    print("-> " + str(train[categorical_features].isnull().values.sum()))
    return train

# %%
def processing_xy(train):
    train['room_coor_d'] = np.sqrt(train['room_coor_x']**2+train['room_coor_x']**2)
    train['screen_coor_d'] = np.sqrt(train['screen_coor_x']**2+train['screen_coor_x']**2)
    return train

# %%
def feature_engineer(train):
    dfs = []
    for c in categorical_features:
        tmp = train.groupby(['session_id','level_group'])[c].agg('nunique')
        tmp.name = tmp.name + '_nunique'
        dfs.append(tmp)
    for c in numerical_features:
        tmp = train.groupby(['session_id','level_group'])[c].agg('mean')
        tmp.name = tmp.name + '_mean'
        dfs.append(tmp)
    for c in numerical_features:
        tmp = train.groupby(['session_id','level_group'])[c].agg('std')
        tmp.name = tmp.name + '_std'
        dfs.append(tmp)
    for c in numerical_features:
        tmp = train.groupby(['session_id','level_group'])[c].agg('max')-train.groupby(['session_id','level_group'])[c].agg('min')
        tmp.name = tmp.name + '_delta'
        dfs.append(tmp)
    for c in categorical_features:
        tmp = train.groupby(['session_id','level_group'])[c].agg('count')
        tmp.name = tmp.name + '_count'
        dfs.append(tmp)
    for c in categorical_features:
        tmp = train.groupby(['session_id','level_group'])[c].agg('sum')
        tmp.name = tmp.name + '_sum'
        dfs.append(tmp)
    
        
    df_engineered = pd.concat(dfs,axis=1)
    df_engineered = df_engineered.fillna(-1)
    df_engineered = df_engineered.reset_index()
    df_engineered = df_engineered.set_index('session_id')
    return df_engineered

# %%
train = processing_na(train)
train = processing_xy(train)
df_tr = feature_engineer(train)
# Out:
# Na of numerical features: 58320192
# -> 0
# Na of categorical features: 41633924
# -> 0

# %%
FEATURES = [c for c in df_tr.columns if c != 'level_group']
ALL_USERS = df_tr.index.unique()
print(len(FEATURES) ,'features, ', len(ALL_USERS) ,'users')
# Out:
# 48 features,  23562 users

# %% [markdown]
# # 💪Train Data

# %% [markdown]
# ## Gridsearch

# %% [markdown]
# Gridsearch is a computationally heavy process. It often takes a tremendous amount of processing time depending on the data and the algorithm. We also know it's because exploring all options like below.
# ```
# params = {'eta': [0.01, 0.1, 1.0], 'gamma': [0.1, 0.5, 0.8],
#                   'n_estimators': [10, 100, 500], 'max_depth':[2, 4, 6],
#                   'min_child_weight': [1, 2], 'nthread': [2] }
# ```

# %%
gkf = GroupKFold(n_splits=5)
skf = StratifiedKFold(n_splits=2, shuffle=True, random_state=1)
oof = pd.DataFrame(data=np.zeros((len(ALL_USERS),18)), index=ALL_USERS)
models = {}
xgb_params = {
    'objective' : 'binary:logistic',
    'eval_metric':'logloss',
}

# Any Params You Want to Scan like below
# 'eta':[0.01, 0.1, 1.0]
# 'gammma':[0.1, 0.4]
# 'learning_rate':[0.04, 0.06]
# 'n_estimator': [1500, 2000, 2500]
# 'max_depth': [5,6]
params = {'eta': [0.01], 'gamma': [0.1], 'learning_rate': [0.06],
                  'n_estimators': [2000], 'max_depth':[5], 
                  'min_child_weight': [1, 2], 'nthread': [2] }
for i, (train_index, test_index) in enumerate(gkf.split(X=df_tr, groups=df_tr.index)):
    print('-'*25)
    print(i)
    # 1->18
    for t in range(1,19):
        print(t,', ',end='')
        
        if t<=3: grp = '0-4'
        elif t<=13: grp = '5-12'
        elif t<=22: grp = '13-22'
            
        # Train
        train_x = df_tr.iloc[train_index]
        train_x = train_x.loc[train_x.level_group == grp]
        train_users = train_x.index.values
        train_y = train_label.loc[train_label.q==t].set_index('session').loc[train_users]
        
        # Valid
        valid_x = df_tr.iloc[test_index]
        valid_x = valid_x.loc[valid_x.level_group == grp]
        valid_users = valid_x.index.values
        valid_y = train_label.loc[train_label.q==t].set_index('session').loc[valid_users]
        
        # Model
        model =  XGBClassifier(**xgb_params)
        clf = GridSearchCV(estimator=model, param_grid=params, 
                    cv=skf, scoring="accuracy", n_jobs=1, verbose=2, return_train_score=False)
        clf.fit(train_x[FEATURES].astype('float32'), train_y['correct'],
                eval_set=[ (valid_x[FEATURES].astype('float32'), valid_y['correct']) ],
                verbose=0)
                
        models[f'{grp}_{t}'] = clf
        oof.loc[valid_users, t-1] = clf.predict_proba(valid_x[FEATURES].astype('float32'))[:,1]
# Out:
# -------------------------
# 0
# 1 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  57.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  51.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  50.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  50.8s
# 2 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  44.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  45.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  42.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  43.3s
# 3 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  48.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  48.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  48.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  48.6s
# 4 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.1s
# 5 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.6s
# 6 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.5s
# 7 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.4s
# 8 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.5s
# 9 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.8s
# 10 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.7s
# 11 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.3s
# 12 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.4s
# 13 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.2s
# 14 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.8s
# 15 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.7s
# 16 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.3s
# 17 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.7s
# 18 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  51.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  51.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  49.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  50.4s
# -------------------------
# 1
# 1 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  51.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  51.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.2s
# 2 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  45.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  45.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  42.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  43.5s
# 3 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  48.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  49.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  48.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  48.1s
# 4 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.9s
# 5 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.7s
# 6 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.0s
# 7 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.7s
# 8 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.6s
# 9 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.2s
# 10 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.5s
# 11 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.2s
# 12 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.6s
# 13 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.6s
# 14 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.9s
# 15 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  56.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.9s
# 16 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.3s
# 17 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  55.3s
# 18 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  51.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  50.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  49.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  50.4s
# -------------------------
# 2
# 1 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  51.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  50.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  50.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  50.1s
# 2 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  45.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  44.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  43.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  43.3s
# 3 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  48.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  48.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  47.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  47.6s
# 4 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  51.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.7s
# 5 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.7s
# 6 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.5s
# 7 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.6s
# 8 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.7s
# 9 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.9s
# 10 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.5s
# 11 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.7s
# 12 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.7s
# 13 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.8s
# 14 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.8s
# 15 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.7s
# 16 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.1s
# 17 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.2s
# 18 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  51.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  50.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  50.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  49.8s
# -------------------------
# 3
# 1 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  50.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  50.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  50.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  50.8s
# 2 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  45.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  45.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  43.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  43.3s
# 3 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  49.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  48.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  48.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  48.1s
# 4 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.5s
# 5 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.8s
# 6 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.5s
# 7 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.4s
# 8 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.4s
# 9 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.9s
# 10 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.7s
# 11 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.4s
# 12 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.8s
# 13 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.8s
# 14 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.9s
# 15 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  55.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  56.0s
# 16 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  55.0s
# 17 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  55.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  55.2s
# 18 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  50.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  50.5s
# -------------------------
# 4
# 1 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  51.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  51.2s
# 2 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  45.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  45.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  43.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  42.8s
# 3 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  49.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  48.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  48.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  48.0s
# 4 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.8s
# 5 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.8s
# 6 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.3s
# 7 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.2s
# 8 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.8s
# 9 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.6s
# 10 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.1s
# 11 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  52.9s
# 12 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  52.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.3s
# 13 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.6s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.0s
# 14 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.7s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.2s
# 15 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  55.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  55.1s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.6s
# 16 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.5s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.2s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.8s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.8s
# 17 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  54.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  53.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  53.9s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  54.1s
# 18 , Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  51.0s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=1, n_estimators=2000, nthread=2; total time=  50.4s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  50.3s
# [CV] END eta=0.01, gamma=0.1, learning_rate=0.06, max_depth=5, min_child_weight=2, n_estimators=2000, nthread=2; total time=  49.2s

# %%
true = oof.copy()
for k in range(18):
    tmp = train_label.loc[train_label.q == k+1].set_index('session').loc[ALL_USERS]
    true[k] = tmp.correct.values

# %%
scores = []; thresholds = []
best_score = 0; best_threshold = 0

for threshold in np.arange(0.4,0.81,0.01):
    print(f'{threshold:.02f}, ',end='')
    preds = (oof.values.reshape((-1))>threshold).astype('int')
    m = f1_score(true.values.reshape((-1)), preds, average='macro')   
    scores.append(m)
    thresholds.append(threshold)
    if m>best_score:
        best_score = m
        best_threshold = threshold
# Out:
# 0.40, 0.41, 0.42, 0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.50, 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.60, 0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.70, 0.71, 0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.80,

# %%
for k in range(18):
    m = f1_score(true[k].values, (oof[k].values>best_threshold).astype('int'), average='macro')
    print(f'Q{k}: F1 =',m)
    
m = f1_score(true.values.reshape((-1)), (oof.values.reshape((-1))>best_threshold).astype('int'), average='macro')
print('-> All F1 =',m)
# Out:
# Q0: F1 = 0.6082969529499797
# Q1: F1 = 0.49452954048140046
# Q2: F1 = 0.4995459976105137
# Q3: F1 = 0.6032986766011054
# Q4: F1 = 0.5755108256389608
# Q5: F1 = 0.5935183800872794
# Q6: F1 = 0.5658133816312518
# Q7: F1 = 0.5341682854561123
# Q8: F1 = 0.5910133776886652
# Q9: F1 = 0.5453826836858431
# Q10: F1 = 0.5647570253283674
# Q11: F1 = 0.5097531781511605
# Q12: F1 = 0.4897607354226844
# Q13: F1 = 0.588059058959282
# Q14: F1 = 0.5510591423868644
# Q15: F1 = 0.5013832243839343
# Q16: F1 = 0.531889671770527
# Q17: F1 = 0.49694386122129586
# -> All F1 = 0.6611613781008407

# %% [markdown]
# # 🥅Submit

# %%
import jo_wilder
try:
    jo_wilder.make_env.__called__ = False
    env.__called__ = False
    type(env)._state = type(type(env)._state).__dict__['INIT']
except:
    pass

env = jo_wilder.make_env()
iter_test = env.iter_test()

# %%
limits = {'0-4':(1,4), '5-12':(4,14), '13-22':(14,19)}

for (test, sample_submission) in iter_test:
    test = processing_na(test)
    test = processing_xy(test)
    df = feature_engineer(test)
    grp = test.level_group.values[0]
    a,b = limits[grp]
    for t in range(a,b):
        clf = models[f'{grp}_{t}']
        p = clf.predict_proba(df[FEATURES].astype('float32'))[:,1]
        pint = [int(x>best_threshold) for x in p ]
        mask = sample_submission.session_id.str.endswith(f'q{t}')
        sample_submission.loc[mask,'correct'] = pint
    
    env.predict(sample_submission)
# Out:
# This version of the API is not optimized and should not be used to estimate the runtime of your code on the hidden test set.
# Na of numerical features: 295
# -> 0
# Na of categorical features: 222
# -> 0
# Na of numerical features: 1229
# -> 0
# Na of categorical features: 877
# -> 99
# Na of numerical features: 1255
# -> 0
# Na of categorical features: 906
# -> 30
# Na of numerical features: 354
# -> 0
# Na of categorical features: 250
# -> 0
# Na of numerical features: 1416
# -> 0
# Na of categorical features: 1180
# -> 36
# Na of numerical features: 1584
# -> 0
# Na of categorical features: 1436
# -> 42
# Na of numerical features: 288
# -> 0
# Na of categorical features: 188
# -> 0
# Na of numerical features: 784
# -> 0
# Na of categorical features: 468
# -> 5
# Na of numerical features: 1193
# -> 0
# Na of categorical features: 828
# -> 21

# %%
submit = pd.read_csv('submission.csv')
submit.head(30)
# Out:
#                session_id  correct
# 0    20090109393214576_q1        1
# 1    20090109393214576_q2        1
# 2    20090109393214576_q3        1
# 3    20090109393214576_q4        1
# 4    20090109393214576_q5        1
# 5    20090109393214576_q6        1
# 6    20090109393214576_q7        1
# 7    20090109393214576_q8        1
# 8    20090109393214576_q9        1
# 9   20090109393214576_q10        0
# 10  20090109393214576_q11        1
# 11  20090109393214576_q12        1
# 12  20090109393214576_q13        0
# 13  20090109393214576_q14        0
# 14  20090109393214576_q15        0
# 15  20090109393214576_q16        1
# 16  20090109393214576_q17        0
# 17  20090109393214576_q18        1
# 18   20090312143683264_q1        1
# 19   20090312143683264_q2        1
# 20   20090312143683264_q3        1
# 21   20090312143683264_q4        1
# 22   20090312143683264_q5        1
# 23   20090312143683264_q6        1
# 24   20090312143683264_q7        1
# 25   20090312143683264_q8        1
# 26   20090312143683264_q9        1
# 27  20090312143683264_q10        0
# 28  20090312143683264_q11        1
# 29  20090312143683264_q12        1
